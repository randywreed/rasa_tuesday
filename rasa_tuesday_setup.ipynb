# %%
import json

# %%
with open('Tuesday_export_lex1.json'.'r') as file:
    lex1=json.load(file)
# Out:
#   File "<ipython-input-2-8fbed6064570>", line 1
#     with open('Tuesday_export_lex1.json'.'r') as file:
#                                            ^
# SyntaxError: invalid syntax

# %%
with open('Tuesday_export_lex1.json','r') as file:
    lex1=json.load(file)

# %%
lex1
# Out:
# oth worth 15% of your final grade. For your article analysis, you will be asked to sign up for a topic, which you will then find an article related to and write an analysis of that article. You will also be asked to peer review articles of others in the class.\xa0"},{"text":"More info on Quizzes","value":"You will be asked to\xa0complete several quizzes on the reading and assignments given in class."},{"text":"More info on Lecture Reflections","value":"You will be expected to write a brief (~200 words) reflection on what you learned and how you felt about class."}]}]}',
#       'maxAttempts': 3},
#      'rejectionStatement': {'messages': [{'groupNumber': 1,
#         'contentType': 'PlainText',
#         'content': 'Alright, hope I helped!'},
#        {'groupNumber': 1,
#         'contentType': 'PlainText',
#         'content': 'OK, looks like you got the hang of it!'},
#        {'groupNumber': 1,
#         'contentType': 'PlainText',
# ...

# %%
for i in lex1['resource']['intents']:
    print(i['name'])
    for m in i['conclusionStatement']['messages']:
        print(m['content'])
# Out:
# coursefulfill
# <speak>REL 1010 Fulfills the General Education requirements in <mark name="gesture:in"/>both Liberal Studies Experience and Literary Studies Designation. This course is a listed as an elective in religion, <break time="500ms"/>so it will contribute to bot a religion major and/or minor.</speak>
# wherefindlec
# <speak>The PowerPoint lectures that your professor recorded can be <mark name="gesture:movement"/>found on the ASUlearn page sorted by unit. The lectures from future units may or may not be available to <mark name="gesture:you"/>you before a certain date.</speak>
# greeting
# <speak>Hi there,<break time="500ms"/>what can<mark name="gesture:self"/> I do for you?<mark name="gesture:you"/></speak>
# <speak>Greetings to <mark name="gesture:you"/>you as well, <break time="500ms"/>do you have any questions for <mark name="gesture:self"/>me?</speak>
# <speak>Hiya,<break time="500ms"/> what can<mark name="gesture:self"/> I help you with?</speak>
# ...

# %%
for i in lex1['resource']['intents']:
    print(i['name'])
    if "conclusionStatement" in i:
        for m in i['conclusionStatement']['messages']:
        print(m['content'])
    else:
        for m in i['followUpPrompt']['prompt']['messages']
        print(m['content'])
        if "rejectionStatement" in i:
            for r in i['followUpPrompt']['rejectionStatement']['messages']:
                print(r['content'])
# Out:
#   File "<ipython-input-6-f3fbf75a4654>", line 5
#     print(m['content'])
#         ^
# IndentationError: expected an indented block

# %%
for i in lex1['resource']['intents']:
    print(i['name'])
    if "conclusionStatement" in i:
        for m in i['conclusionStatement']['messages']:
            print(m['content'])
    else:
        for m in i['followUpPrompt']['prompt']['messages']
            print(m['content'])
        if "rejectionStatement" in i:
            for r in i['followUpPrompt']['rejectionStatement']['messages']:
                print(r['content'])
# Out:
#   File "<ipython-input-7-814d51b9f4ac>", line 7
#     for m in i['followUpPrompt']['prompt']['messages']
#                                                       ^
# SyntaxError: invalid syntax

# %%
for i in lex1['resource']['intents']:
    print(i['name'])
    if "conclusionStatement" in i:
        for m in i['conclusionStatement']['messages']:
            print(m['content'])
    else:
        for m in i['followUpPrompt']['prompt']['messages']:
            print(m['content'])
        if "rejectionStatement" in i:
            for r in i['followUpPrompt']['rejectionStatement']['messages']:
                print(r['content'])
# Out:
# coursefulfill
# <speak>REL 1010 Fulfills the General Education requirements in <mark name="gesture:in"/>both Liberal Studies Experience and Literary Studies Designation. This course is a listed as an elective in religion, <break time="500ms"/>so it will contribute to bot a religion major and/or minor.</speak>
# wherefindlec
# <speak>The PowerPoint lectures that your professor recorded can be <mark name="gesture:movement"/>found on the ASUlearn page sorted by unit. The lectures from future units may or may not be available to <mark name="gesture:you"/>you before a certain date.</speak>
# greeting
# <speak>Hi there,<break time="500ms"/>what can<mark name="gesture:self"/> I do for you?<mark name="gesture:you"/></speak>
# <speak>Greetings to <mark name="gesture:you"/>you as well, <break time="500ms"/>do you have any questions for <mark name="gesture:self"/>me?</speak>
# <speak>Hiya,<break time="500ms"/> what can<mark name="gesture:self"/> I help you with?</speak>
# ...

# %%
new_list=[]
message_list=[]
for i in lex1['resource']['intents']:
    print(i['name'])
    if "conclusionStatement" in i:
        for m in i['conclusionStatement']['messages']:
            print(m['content'])
            message_list.append(m['content'])
    else:
        for m in i['followUpPrompt']['prompt']['messages']:
            print(m['content'])
            message_list.append(m['content'])
        if "rejectionStatement" in i:
            for r in i['followUpPrompt']['rejectionStatement']['messages']:
                print(r['content'])
                message_list.append(r['content'])
    new_list.append("utter_"+i['name'],message_list)
    message_list=[]
# Out:
# coursefulfill
# <speak>REL 1010 Fulfills the General Education requirements in <mark name="gesture:in"/>both Liberal Studies Experience and Literary Studies Designation. This course is a listed as an elective in religion, <break time="500ms"/>so it will contribute to bot a religion major and/or minor.</speak>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-4f50411c4668> in <module>
#      15                 print(r['content'])
#      16                 message_list.append(r['content'])
# ---> 17     new_list.append("utter_"+i['name'],message_list)
#      18     message_list=[]
#
# TypeError: append() takes exactly one argument (2 given)

# %%
new_list=[]
message_list=[]
for i in lex1['resource']['intents']:
    print(i['name'])
    if "conclusionStatement" in i:
        for m in i['conclusionStatement']['messages']:
            print(m['content'])
            message_list.append(m['content'])
    else:
        for m in i['followUpPrompt']['prompt']['messages']:
            print(m['content'])
            message_list.append(m['content'])
        if "rejectionStatement" in i:
            for r in i['followUpPrompt']['rejectionStatement']['messages']:
                print(r['content'])
                message_list.append(r['content'])
    new_list.append(["utter_"+i['name'],message_list])
    message_list=[]
# Out:
# coursefulfill
# <speak>REL 1010 Fulfills the General Education requirements in <mark name="gesture:in"/>both Liberal Studies Experience and Literary Studies Designation. This course is a listed as an elective in religion, <break time="500ms"/>so it will contribute to bot a religion major and/or minor.</speak>
# wherefindlec
# <speak>The PowerPoint lectures that your professor recorded can be <mark name="gesture:movement"/>found on the ASUlearn page sorted by unit. The lectures from future units may or may not be available to <mark name="gesture:you"/>you before a certain date.</speak>
# greeting
# <speak>Hi there,<break time="500ms"/>what can<mark name="gesture:self"/> I do for you?<mark name="gesture:you"/></speak>
# <speak>Greetings to <mark name="gesture:you"/>you as well, <break time="500ms"/>do you have any questions for <mark name="gesture:self"/>me?</speak>
# <speak>Hiya,<break time="500ms"/> what can<mark name="gesture:self"/> I help you with?</speak>
# ...

# %%
new_list
# Out:
# [['utter_coursefulfill',
#   ['<speak>REL 1010 Fulfills the General Education requirements in <mark name="gesture:in"/>both Liberal Studies Experience and Literary Studies Designation. This course is a listed as an elective in religion, <break time="500ms"/>so it will contribute to bot a religion major and/or minor.</speak>']],
#  ['utter_wherefindlec',
#   ['<speak>The PowerPoint lectures that your professor recorded can be <mark name="gesture:movement"/>found on the ASUlearn page sorted by unit. The lectures from future units may or may not be available to <mark name="gesture:you"/>you before a certain date.</speak>']],
#  ['utter_greeting',
#   ['<speak>Hi there,<break time="500ms"/>what can<mark name="gesture:self"/> I do for you?<mark name="gesture:you"/></speak>',
#    '<speak>Greetings to <mark name="gesture:you"/>you as well, <break time="500ms"/>do you have any questions for <mark name="gesture:self"/>me?</speak>',
# ...

# %%
new_dict=dict(new_list)

# %%
new_dict
# Out:
# {'utter_coursefulfill': ['<speak>REL 1010 Fulfills the General Education requirements in <mark name="gesture:in"/>both Liberal Studies Experience and Literary Studies Designation. This course is a listed as an elective in religion, <break time="500ms"/>so it will contribute to bot a religion major and/or minor.</speak>'],
#  'utter_wherefindlec': ['<speak>The PowerPoint lectures that your professor recorded can be <mark name="gesture:movement"/>found on the ASUlearn page sorted by unit. The lectures from future units may or may not be available to <mark name="gesture:you"/>you before a certain date.</speak>'],
#  'utter_greeting': ['<speak>Hi there,<break time="500ms"/>what can<mark name="gesture:self"/> I do for you?<mark name="gesture:you"/></speak>',
#   '<speak>Greetings to <mark name="gesture:you"/>you as well, <break time="500ms"/>do you have any questions for <mark name="gesture:self"/>me?</speak>',
# ...

# %%
new_list=[]
message_list=[]
for i in lex1['resource']['intents']:
    print(i['name'])
    if "conclusionStatement" in i:
        for m in i['conclusionStatement']['messages']:
            print(m['content'])
            message_list.append(dict('text',m['content']))
    else:
        for m in i['followUpPrompt']['prompt']['messages']:
            print(m['content'])
            message_list.append(dict('text',m['content']))
        if "rejectionStatement" in i:
            for r in i['followUpPrompt']['rejectionStatement']['messages']:
                print(r['content'])
                message_list.append(dict('text',r['content']))
    new_list.append(["utter_"+i['name'],message_list])
    message_list=[]
# Out:
# coursefulfill
# <speak>REL 1010 Fulfills the General Education requirements in <mark name="gesture:in"/>both Liberal Studies Experience and Literary Studies Designation. This course is a listed as an elective in religion, <break time="500ms"/>so it will contribute to bot a religion major and/or minor.</speak>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-4243e929d201> in <module>
#       6         for m in i['conclusionStatement']['messages']:
#       7             print(m['content'])
# ----> 8             message_list.append(dict('text',m['content']))
#       9     else:
#      10         for m in i['followUpPrompt']['prompt']['messages']:
#
# TypeError: dict expected at most 1 arguments, got 2

# %%
new_list
# Out:
# []

# %%
new_list=[]
message_list=[]
for i in lex1['resource']['intents']:
    print(i['name'])
    if "conclusionStatement" in i:
        for m in i['conclusionStatement']['messages']:
            print(m['content'])
            message_list.append(dict({'text':m['content']}))
    else:
        for m in i['followUpPrompt']['prompt']['messages']:
            print(m['content'])
            message_list.append(dict({'text':m['content']}))
        if "rejectionStatement" in i:
            for r in i['followUpPrompt']['rejectionStatement']['messages']:
                print(r['content'])
                message_list.append(dict({'text':r['content']}))
    new_list.append(["utter_"+i['name'],message_list])
    message_list=[]
# Out:
# coursefulfill
# <speak>REL 1010 Fulfills the General Education requirements in <mark name="gesture:in"/>both Liberal Studies Experience and Literary Studies Designation. This course is a listed as an elective in religion, <break time="500ms"/>so it will contribute to bot a religion major and/or minor.</speak>
# wherefindlec
# <speak>The PowerPoint lectures that your professor recorded can be <mark name="gesture:movement"/>found on the ASUlearn page sorted by unit. The lectures from future units may or may not be available to <mark name="gesture:you"/>you before a certain date.</speak>
# greeting
# <speak>Hi there,<break time="500ms"/>what can<mark name="gesture:self"/> I do for you?<mark name="gesture:you"/></speak>
# <speak>Greetings to <mark name="gesture:you"/>you as well, <break time="500ms"/>do you have any questions for <mark name="gesture:self"/>me?</speak>
# <speak>Hiya,<break time="500ms"/> what can<mark name="gesture:self"/> I help you with?</speak>
# ...

# %%
new
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-389cc6b7ae5a> in <module>
# ----> 1 new
#
# NameError: name 'new' is not defined

# %%
new_list
# Out:
# [['utter_coursefulfill',
#   [{'text': '<speak>REL 1010 Fulfills the General Education requirements in <mark name="gesture:in"/>both Liberal Studies Experience and Literary Studies Designation. This course is a listed as an elective in religion, <break time="500ms"/>so it will contribute to bot a religion major and/or minor.</speak>'}]],
#  ['utter_wherefindlec',
#   [{'text': '<speak>The PowerPoint lectures that your professor recorded can be <mark name="gesture:movement"/>found on the ASUlearn page sorted by unit. The lectures from future units may or may not be available to <mark name="gesture:you"/>you before a certain date.</speak>'}]],
#  ['utter_greeting',
#   [{'text': '<speak>Hi there,<break time="500ms"/>what can<mark name="gesture:self"/> I do for you?<mark name="gesture:you"/></speak>'},
#    {'text': '<speak>Greetings to <mark name="gesture:you"/>you as well, <break time="500ms"/>do you have any questions for <mark name="gesture:self"/>me?</speak>'},
# ...

# %%
new_dict=dict(new_list)

# %%
new_dict
# Out:
# {'utter_coursefulfill': [{'text': '<speak>REL 1010 Fulfills the General Education requirements in <mark name="gesture:in"/>both Liberal Studies Experience and Literary Studies Designation. This course is a listed as an elective in religion, <break time="500ms"/>so it will contribute to bot a religion major and/or minor.</speak>'}],
#  'utter_wherefindlec': [{'text': '<speak>The PowerPoint lectures that your professor recorded can be <mark name="gesture:movement"/>found on the ASUlearn page sorted by unit. The lectures from future units may or may not be available to <mark name="gesture:you"/>you before a certain date.</speak>'}],
#  'utter_greeting': [{'text': '<speak>Hi there,<break time="500ms"/>what can<mark name="gesture:self"/> I do for you?<mark name="gesture:you"/></speak>'},
#   {'text': '<speak>Greetings to <mark name="gesture:you"/>you as well, <break time="500ms"/>do you have any questions for <mark name="gesture:self"/>me?</speak>'},
# ...

# %%
import yaml
with open('tuesday_responses','w') as resp:
    documents=yaml.dump(new_dict,resp)

# %%
import yaml
with open('tuesday_responses.yml','w') as resp:
    documents=yaml.dump(new_dict,resp)

# %%
# !pip install lxml
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/home/randy/anaconda3/bin/python -m pip install --upgrade pip' command.
